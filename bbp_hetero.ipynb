# %% [markdown]
# <a href="https://colab.research.google.com/github/EdWangLoDaSc/Dropout-as-a-Grid-Search_Representing-Model-Uncertainty-in-Deep-Learning/blob/main/bbp_hetero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
# !pip install GPy
import GPy
import pandas as pd
import zipfile
import urllib.request
import time
import copy
import math
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim import Optimizer
from sklearn.model_selection import KFold

from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm, trange
from google.colab import files
# %config InlineBackend.figure_format = 'svg'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: torch-0.4.1-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.13.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchvision) (4.1.1)
# Requirement already satisfied: torch==1.12.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.12.0+cu113)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GPy
#   Downloading GPy-1.10.0.tar.gz (959 kB)
#      |████████████████████████████████| 959 kB 7.0 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from GPy) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from GPy) (1.15.0)
# Collecting paramz>=0.9.0
#   Downloading paramz-0.9.5.tar.gz (71 kB)
#      |████████████████████████████████| 71 kB 9.8 MB/s
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from GPy) (0.29.30)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from GPy) (1.7.3)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from paramz>=0.9.0->GPy) (4.4.2)
# Building wheels for collected packages: GPy, paramz
#   Building wheel for GPy (setup.py) ... done
#   Created wheel for GPy: filename=GPy-1.10.0-cp37-cp37m-linux_x86_64.whl size=2565109 sha256=b8b0ee368f618bc52cc50b167aefcfe74279379fa157d0d2de5cc70c9ed616ee
#   Stored in directory: /root/.cache/pip/wheels/f7/18/28/dd1ce0192a81b71a3b086fd952511d088b21e8359ea496860a
#   Building wheel for paramz (setup.py) ... done
#   Created wheel for paramz: filename=paramz-0.9.5-py3-none-any.whl size=102566 sha256=5f37903a3c22bf5016df561a2e5711de2ed07880cc31dce1f15f9f2fbb344cb6
#   Stored in directory: /root/.cache/pip/wheels/c8/95/f5/ce28482da28162e6028c4b3a32c41d147395825b3cd62bc810
# Successfully built GPy paramz
# Installing collected packages: paramz, GPy
# Successfully installed GPy-1.10.0 paramz-0.9.5

# %%
torch.cuda.device(0)
torch.cuda.get_device_name(torch.cuda.current_device())
# Out:
# 'Tesla T4'

# %%
def to_variable(var=(), cuda=True, volatile=False):
    out = []
    for v in var:
        
        if isinstance(v, np.ndarray):
            v = torch.from_numpy(v).type(torch.FloatTensor)

        if not v.is_cuda and cuda:
            v = v.cuda()

        if not isinstance(v, Variable):
            v = Variable(v, volatile=volatile)

        out.append(v)
    return out

# %%
def log_gaussian_loss(output, target, sigma, no_dim, sum_reduce=True):
    exponent = -0.5*(target - output)**2/sigma**2
    log_coeff = -no_dim*torch.log(sigma) - 0.5*no_dim*np.log(2*np.pi)
    
    if sum_reduce:
        return -(log_coeff + exponent).sum()
    else:
        return -(log_coeff + exponent)


def get_kl_divergence(weights, prior, varpost):
    prior_loglik = prior.loglik(weights)
    
    varpost_loglik = varpost.loglik(weights)
    varpost_lik = varpost_loglik.exp()
    
    return (varpost_lik*(varpost_loglik - prior_loglik)).sum()


class gaussian:
    def __init__(self, mu, sigma):
        self.mu = mu
        self.sigma = sigma
        
    def loglik(self, weights):
        exponent = -0.5*(weights - self.mu)**2/self.sigma**2
        log_coeff = -0.5*(np.log(2*np.pi) + 2*np.log(self.sigma))
        
        return (exponent + log_coeff).sum()

# %%
class BayesLinear_Normalq(nn.Module):
    def __init__(self, input_dim, output_dim, prior):
        super(BayesLinear_Normalq, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.prior = prior
        
        scale = (2/self.input_dim)**0.5
        rho_init = np.log(np.exp((2/self.input_dim)**0.5) - 1)
        self.weight_mus = nn.Parameter(torch.Tensor(self.input_dim, self.output_dim).uniform_(-0.01, 0.01))
        self.weight_rhos = nn.Parameter(torch.Tensor(self.input_dim, self.output_dim).uniform_(-3, -3))
        
        self.bias_mus = nn.Parameter(torch.Tensor(self.output_dim).uniform_(-0.01, 0.01))
        self.bias_rhos = nn.Parameter(torch.Tensor(self.output_dim).uniform_(-4, -3))
        
    def forward(self, x, sample = True):
        
        if sample:
            # sample gaussian noise for each weight and each bias
            weight_epsilons = Variable(self.weight_mus.data.new(self.weight_mus.size()).normal_())
            bias_epsilons =  Variable(self.bias_mus.data.new(self.bias_mus.size()).normal_())
            
            # calculate the weight and bias stds from the rho parameters
            weight_stds = torch.log(1 + torch.exp(self.weight_rhos))
            bias_stds = torch.log(1 + torch.exp(self.bias_rhos))
            
            # calculate samples from the posterior from the sampled noise and mus/stds
            weight_sample = self.weight_mus + weight_epsilons*weight_stds
            bias_sample = self.bias_mus + bias_epsilons*bias_stds
            
            output = torch.mm(x, weight_sample) + bias_sample
            
            # computing the KL loss term
            prior_cov, varpost_cov = self.prior.sigma**2, weight_stds**2
            KL_loss = 0.5*(torch.log(prior_cov/varpost_cov)).sum() - 0.5*weight_stds.numel()
            KL_loss = KL_loss + 0.5*(varpost_cov/prior_cov).sum()
            KL_loss = KL_loss + 0.5*((self.weight_mus - self.prior.mu)**2/prior_cov).sum()
            
            prior_cov, varpost_cov = self.prior.sigma**2, bias_stds**2
            KL_loss = KL_loss + 0.5*(torch.log(prior_cov/varpost_cov)).sum() - 0.5*bias_stds.numel()
            KL_loss = KL_loss + 0.5*(varpost_cov/prior_cov).sum()
            KL_loss = KL_loss + 0.5*((self.bias_mus - self.prior.mu)**2/prior_cov).sum()
            
            return output, KL_loss
        
        else:
            output = torch.mm(x, self.weight_mus) + self.bias_mus
            return output, KL_loss
        
    def sample_layer(self, no_samples):
        all_samples = []
        for i in range(no_samples):
            # sample gaussian noise for each weight and each bias
            weight_epsilons = Variable(self.weight_mus.data.new(self.weight_mus.size()).normal_())
            
            # calculate the weight and bias stds from the rho parameters
            weight_stds = torch.log(1 + torch.exp(self.weight_rhos))
            
            # calculate samples from the posterior from the sampled noise and mus/stds
            weight_sample = self.weight_mus + weight_epsilons*weight_stds
            
            all_samples += weight_sample.view(-1).cpu().data.numpy().tolist()
            
        return all_samples

# %%
class BBP_Heteroscedastic_Model(nn.Module):
    def __init__(self, input_dim, output_dim, num_units):
        super(BBP_Heteroscedastic_Model, self).__init__()
        
        self.input_dim = input_dim
        self.output_dim = output_dim
        
        # network with two hidden and one output layer
        self.layer1 = BayesLinear_Normalq(input_dim, num_units, gaussian(0, 1))
        self.layer2 = BayesLinear_Normalq(num_units, 2*output_dim, gaussian(0, 1))
        
        # activation to be used between hidden layers
        self.activation = nn.ReLU(inplace = True)
    
    def forward(self, x):
        
        KL_loss_total = 0
        x = x.view(-1, self.input_dim)
        
        x, KL_loss = self.layer1(x)
        KL_loss_total = KL_loss_total + KL_loss
        x = self.activation(x)
        
        x, KL_loss = self.layer2(x)
        KL_loss_total = KL_loss_total + KL_loss
        
        return x, KL_loss_total

# %%
class BBP_Heteroscedastic_Model_Wrapper:
    def __init__(self, network, learn_rate, batch_size, no_batches):
        
        self.learn_rate = learn_rate
        self.batch_size = batch_size
        self.no_batches = no_batches
        
        self.network = network
        self.network.cuda()
        
        self.optimizer = torch.optim.Adam(self.network.parameters(), lr = self.learn_rate)
        self.loss_func = log_gaussian_loss
    
    def fit(self, x, y, no_samples):
        x, y = to_variable(var=(x, y), cuda=True)
        
        # reset gradient and total loss
        self.optimizer.zero_grad()
        fit_loss_total = 0
        
        for i in range(no_samples):
            output, KL_loss_total = self.network(x)

            # calculate fit loss based on mean and standard deviation of output
            fit_loss = self.loss_func(output[:, :1], y, output[:, 1:].exp(), 1)
            fit_loss_total = fit_loss_total + fit_loss
        
        KL_loss_total = KL_loss_total/self.no_batches
        total_loss = (fit_loss_total + KL_loss_total)/(no_samples*x.shape[0])
        total_loss.backward()
        self.optimizer.step()

        return fit_loss_total/no_samples, KL_loss_total
    
    def get_loss_and_rmse(self, x, y, no_samples):
        x, y = to_variable(var=(x, y), cuda=True)
        
        means, stds = [], []
        for i in range(no_samples):
            output, KL_loss_total = self.network(x)
            means.append(output[:, :1, None])
            stds.append(output[:, 1:, None].exp())
            
        means, stds = torch.cat(means, 2), torch.cat(stds, 2)
        mean = means.mean(dim=2)
        std = (means.var(dim=2) + stds.mean(dim=2)**2)**0.5
            
        # calculate fit loss based on mean and standard deviation of output
        logliks = self.loss_func(output[:, :1], y, output[:, 1:].exp(), 1, sum_reduce=False)
        rmse = float((((mean - y)**2).mean()**0.5).cpu().data)

        return logliks, rmse

# %%
class BBP_Heteroscedastic_Model_UCI(nn.Module):
    def __init__(self, input_dim, output_dim, num_units):
        super(BBP_Heteroscedastic_Model_UCI, self).__init__()
        
        self.input_dim = input_dim
        self.output_dim = output_dim
        
        # network with two hidden and one output layer
        self.layer1 = BayesLinear_Normalq(input_dim, num_units, gaussian(0, 1))
        self.layer2 = BayesLinear_Normalq(num_units, num_units, gaussian(0, 1))
        self.layer3 = BayesLinear_Normalq(num_units, 2*output_dim, gaussian(0, 1))
        
        # activation to be used between hidden layers
        self.activation = nn.ReLU(inplace = True)
    
    def forward(self, x):
        
        KL_loss_total = 0
        x = x.view(-1, self.input_dim)
        
        x, KL_loss = self.layer1(x)
        KL_loss_total = KL_loss_total + KL_loss
        x = self.activation(x)
        
        x, KL_loss = self.layer2(x)
        KL_loss_total = KL_loss_total + KL_loss
        
        return x, KL_loss_total

def train_BBP(data, n_splits, num_epochs, num_units, learn_rate, log_every):
    kf = KFold(n_splits=n_splits)
    in_dim = data.shape[1] - 1
    train_logliks, test_logliks = [], []
    train_rmses, test_rmses = [], []

    for i, idx in enumerate(kf.split(data)):
        print('FOLD %d:' % i)

        train_index, test_index = idx

        x_train, y_train = data[train_index, :in_dim], data[train_index, in_dim:]
        x_test, y_test = data[test_index, :in_dim], data[test_index, in_dim:]

        x_means, x_stds = x_train.mean(axis = 0), x_train.var(axis = 0)**0.5
        y_means, y_stds = y_train.mean(axis = 0), y_train.var(axis = 0)**0.5

        #x_train = (x_train - x_means)/x_stds
        #y_train = (y_train - y_means)/y_stds

        #x_test = (x_test - x_means)/x_stds
        #y_test = (y_test - y_means)/y_stds

        batch_size, nb_train = len(x_train), len(x_train)

        net = BBP_Heteroscedastic_Model_Wrapper(network=BBP_Heteroscedastic_Model_UCI(input_dim=x_test.shape[-1], output_dim=1, num_units=num_units),
                                                learn_rate=1e-2, batch_size=batch_size, no_batches=1)

        fit_loss_train = np.zeros(num_epochs)
        KL_loss_train = np.zeros(num_epochs)
        total_loss = np.zeros(num_epochs)

        best_net, best_loss = None, float('inf')

        for i in range(num_epochs):

            fit_loss, KL_loss = net.fit(x_train, y_train, no_samples = 20)
            fit_loss_train[i] += fit_loss.cpu().data.numpy()
            KL_loss_train[i] += KL_loss.cpu().data.numpy()

            total_loss[i] = fit_loss_train[i] + KL_loss_train[i]

            if fit_loss < best_loss:
                best_loss = fit_loss
                best_net = copy.deepcopy(net.network)

            if i % log_every == 0 or i == num_epochs - 1:

                train_losses, train_rmse = net.get_loss_and_rmse(x_train, y_train, 20)
                test_losses, test_rmse = net.get_loss_and_rmse(x_test, y_test, 20)

                print('Epoch: %s/%d, Train loglik = %.3f, Test loglik = %.3f, Train RMSE = %.3f, Test RMSE = %.3f' %\
                      (str(i+1).zfill(3), num_epochs, -train_losses.mean() - np.log(y_stds)[0],
                       -test_losses.mean() - np.log(y_stds)[0], y_stds*train_rmse, y_stds*test_rmse))


        train_losses, train_rmse = net.get_loss_and_rmse(x_train, y_train, 20)
        test_losses, test_rmse = net.get_loss_and_rmse(x_test, y_test, 20)

        train_logliks.append((train_losses.cpu().data.numpy().mean() + np.log(y_stds)[0]))
        test_logliks.append((test_losses.cpu().data.numpy().mean() + np.log(y_stds)[0]))

        train_rmses.append(y_stds*train_rmse)
        test_rmses.append(y_stds*test_rmse)

    print('Train log. lik. = %6.3f +/- %6.3f' % (-np.array(train_logliks).mean(), np.array(train_logliks).var()**0.5))
    print('Test  log. lik. = %6.3f +/- %6.3f' % (-np.array(test_logliks).mean(), np.array(test_logliks).var()**0.5))
    print('Train RMSE      = %6.3f +/- %6.3f' % (np.array(train_rmses).mean(), np.array(train_rmses).var()**0.5))
    print('Test  RMSE      = %6.3f +/- %6.3f' % (np.array(test_rmses).mean(), np.array(test_rmses).var()**0.5))

    return best_net

# %%
batch_size = 64
data = pd.read_csv('/content/drive/MyDrive/bayesian-deep-learning-master/data/Datasets.csv').values
model = train_BBP(data, n_splits=10, num_epochs=500, num_units=120, learn_rate=1e-2, log_every=30)
# Out:
# FOLD 0:
# Epoch: 001/500, Train loglik = -14.579, Test loglik = -10.223, Train RMSE = 6.415, Test RMSE = 5.275
# Epoch: 031/500, Train loglik = -2.529, Test loglik = -2.966, Train RMSE = 2.173, Test RMSE = 2.837
# Epoch: 061/500, Train loglik = -1.255, Test loglik = -1.750, Train RMSE = 0.625, Test RMSE = 1.020
# Epoch: 091/500, Train loglik = -0.928, Test loglik = -2.062, Train RMSE = 0.496, Test RMSE = 1.004
# Epoch: 121/500, Train loglik = -0.879, Test loglik = -1.473, Train RMSE = 0.388, Test RMSE = 1.094
# Epoch: 151/500, Train loglik = -0.512, Test loglik = -2.120, Train RMSE = 0.282, Test RMSE = 1.000
# Epoch: 181/500, Train loglik = -0.681, Test loglik = -1.809, Train RMSE = 0.272, Test RMSE = 1.014
# Epoch: 211/500, Train loglik = -0.701, Test loglik = -1.816, Train RMSE = 0.459, Test RMSE = 1.049
# Epoch: 241/500, Train loglik = -0.447, Test loglik = -3.172, Train RMSE = 0.218, Test RMSE = 1.004
# Epoch: 271/500, Train loglik = -0.226, Test loglik = -3.010, Train RMSE = 0.334, Test RMSE = 1.020
# Epoch: 301/500, Train loglik = -0.478, Test loglik = -2.772, Train RMSE = 0.412, Test RMSE = 1.000
# Epoch: 331/500, Train loglik = -0.367, Test loglik = -3.101, Train RMSE = 0.240, Test RMSE = 0.982
# Epoch: 361/500, Train loglik = -0.864, Test loglik = -1.738, Train RMSE = 0.414, Test RMSE = 1.074
# Epoch: 391/500, Train loglik = -0.022, Test loglik = -6.931, Train RMSE = 0.147, Test RMSE = 0.942
# Epoch: 421/500, Train loglik = -4.416, Test loglik = -4.854, Train RMSE = 1.254, Test RMSE = 1.596
# Epoch: 451/500, Train loglik = -1.211, Test loglik = -1.774, Train RMSE = 0.837, Test RMSE = 1.450
# Epoch: 481/500, Train loglik = -0.004, Test loglik = -4.359, Train RMSE = 0.181, Test RMSE = 0.937
# Epoch: 500/500, Train loglik = 0.043, Test loglik = -6.424, Train RMSE = 0.146, Test RMSE = 0.942
# FOLD 1:
# Epoch: 001/500, Train loglik = -13.192, Test loglik = -10.459, Train RMSE = 6.292, Test RMSE = 5.454
# Epoch: 031/500, Train loglik = -2.222, Test loglik = -2.442, Train RMSE = 1.944, Test RMSE = 1.969
# Epoch: 061/500, Train loglik = -1.233, Test loglik = -1.675, Train RMSE = 0.667, Test RMSE = 0.954
# Epoch: 091/500, Train loglik = -0.998, Test loglik = -1.659, Train RMSE = 0.622, Test RMSE = 1.039
# Epoch: 121/500, Train loglik = -1.147, Test loglik = -3.021, Train RMSE = 0.448, Test RMSE = 0.982
# Epoch: 151/500, Train loglik = -0.927, Test loglik = -1.543, Train RMSE = 0.709, Test RMSE = 0.993
# Epoch: 181/500, Train loglik = -1.061, Test loglik = -1.461, Train RMSE = 0.636, Test RMSE = 0.976
# Epoch: 211/500, Train loglik = -0.456, Test loglik = -2.563, Train RMSE = 0.284, Test RMSE = 0.950
# Epoch: 241/500, Train loglik = -0.357, Test loglik = -2.864, Train RMSE = 0.235, Test RMSE = 0.932
# Epoch: 271/500, Train loglik = -0.612, Test loglik = -2.763, Train RMSE = 0.307, Test RMSE = 1.051
# Epoch: 301/500, Train loglik = -0.110, Test loglik = -7.801, Train RMSE = 0.183, Test RMSE = 0.965
# Epoch: 331/500, Train loglik = -0.733, Test loglik = -2.908, Train RMSE = 0.235, Test RMSE = 0.984
# Epoch: 361/500, Train loglik = -0.303, Test loglik = -3.376, Train RMSE = 0.201, Test RMSE = 0.914
# Epoch: 391/500, Train loglik = -0.021, Test loglik = -8.906, Train RMSE = 0.178, Test RMSE = 0.927
# Epoch: 421/500, Train loglik = -0.991, Test loglik = -1.320, Train RMSE = 0.161, Test RMSE = 0.933
# Epoch: 451/500, Train loglik = -0.469, Test loglik = -2.170, Train RMSE = 0.222, Test RMSE = 0.966
# Epoch: 481/500, Train loglik = -2.792, Test loglik = -2.553, Train RMSE = 2.145, Test RMSE = 2.199
# Epoch: 500/500, Train loglik = -0.339, Test loglik = -3.590, Train RMSE = 0.280, Test RMSE = 0.915
# FOLD 2:
# Epoch: 001/500, Train loglik = -11.297, Test loglik = -13.128, Train RMSE = 6.536, Test RMSE = 6.401
# Epoch: 031/500, Train loglik = -1.889, Test loglik = -2.052, Train RMSE = 1.046, Test RMSE = 1.368
# Epoch: 061/500, Train loglik = -1.155, Test loglik = -1.755, Train RMSE = 0.613, Test RMSE = 1.143
# Epoch: 091/500, Train loglik = -1.380, Test loglik = -2.533, Train RMSE = 0.443, Test RMSE = 1.223
# Epoch: 121/500, Train loglik = -1.766, Test loglik = -3.899, Train RMSE = 0.438, Test RMSE = 1.245
# Epoch: 151/500, Train loglik = -0.617, Test loglik = -3.206, Train RMSE = 0.318, Test RMSE = 1.223
# Epoch: 181/500, Train loglik = -0.873, Test loglik = -3.060, Train RMSE = 0.251, Test RMSE = 1.206
# Epoch: 211/500, Train loglik = -0.537, Test loglik = -3.222, Train RMSE = 0.225, Test RMSE = 1.223
# Epoch: 241/500, Train loglik = -0.638, Test loglik = -4.526, Train RMSE = 0.354, Test RMSE = 1.267
# Epoch: 271/500, Train loglik = -0.658, Test loglik = -10.462, Train RMSE = 0.244, Test RMSE = 1.260
# Epoch: 301/500, Train loglik = -0.596, Test loglik = -13.011, Train RMSE = 0.377, Test RMSE = 1.287
# Epoch: 331/500, Train loglik = -2.993, Test loglik = -2.873, Train RMSE = 2.794, Test RMSE = 2.716
# Epoch: 361/500, Train loglik = -0.529, Test loglik = -3.557, Train RMSE = 0.341, Test RMSE = 1.276
# Epoch: 391/500, Train loglik = -0.183, Test loglik = -10.516, Train RMSE = 0.174, Test RMSE = 1.258
# Epoch: 421/500, Train loglik = -0.531, Test loglik = -7.694, Train RMSE = 0.342, Test RMSE = 1.271
# Epoch: 451/500, Train loglik = -0.569, Test loglik = -9.683, Train RMSE = 0.346, Test RMSE = 1.265
# Epoch: 481/500, Train loglik = -2.173, Test loglik = -2.283, Train RMSE = 1.339, Test RMSE = 1.923
# Epoch: 500/500, Train loglik = -0.707, Test loglik = -4.015, Train RMSE = 0.377, Test RMSE = 1.315
# FOLD 3:
# Epoch: 001/500, Train loglik = -12.763, Test loglik = -15.548, Train RMSE = 6.297, Test RMSE = 7.180
# Epoch: 031/500, Train loglik = -1.897, Test loglik = -1.941, Train RMSE = 1.066, Test RMSE = 1.153
# Epoch: 061/500, Train loglik = -1.499, Test loglik = -2.713, Train RMSE = 0.613, Test RMSE = 0.935
# Epoch: 091/500, Train loglik = -1.026, Test loglik = -1.913, Train RMSE = 0.487, Test RMSE = 0.987
# Epoch: 121/500, Train loglik = -0.959, Test loglik = -2.628, Train RMSE = 0.438, Test RMSE = 1.090
# Epoch: 151/500, Train loglik = -0.578, Test loglik = -2.872, Train RMSE = 0.300, Test RMSE = 1.014
# Epoch: 181/500, Train loglik = -0.387, Test loglik = -3.408, Train RMSE = 0.253, Test RMSE = 1.023
# Epoch: 211/500, Train loglik = -0.589, Test loglik = -2.319, Train RMSE = 0.225, Test RMSE = 1.030
# Epoch: 241/500, Train loglik = -0.695, Test loglik = -2.624, Train RMSE = 0.327, Test RMSE = 1.100
# Epoch: 271/500, Train loglik = -0.266, Test loglik = -7.289, Train RMSE = 0.198, Test RMSE = 1.008
# Epoch: 301/500, Train loglik = -0.223, Test loglik = -3.946, Train RMSE = 0.199, Test RMSE = 0.993
# Epoch: 331/500, Train loglik = -0.235, Test loglik = -5.851, Train RMSE = 0.314, Test RMSE = 1.001
# Epoch: 361/500, Train loglik = 0.073, Test loglik = -6.647, Train RMSE = 0.175, Test RMSE = 0.992
# Epoch: 391/500, Train loglik = -1.631, Test loglik = -2.112, Train RMSE = 1.171, Test RMSE = 1.734
# Epoch: 421/500, Train loglik = -0.106, Test loglik = -5.236, Train RMSE = 0.160, Test RMSE = 1.009
# Epoch: 451/500, Train loglik = -1.786, Test loglik = -13.977, Train RMSE = 0.248, Test RMSE = 0.983
# Epoch: 481/500, Train loglik = -0.229, Test loglik = -2.921, Train RMSE = 0.146, Test RMSE = 0.978
# Epoch: 500/500, Train loglik = -0.319, Test loglik = -2.463, Train RMSE = 0.210, Test RMSE = 0.994
# FOLD 4:
# Epoch: 001/500, Train loglik = -14.271, Test loglik = -15.507, Train RMSE = 6.358, Test RMSE = 6.739
# Epoch: 031/500, Train loglik = -2.563, Test loglik = -2.543, Train RMSE = 2.033, Test RMSE = 2.481
# Epoch: 061/500, Train loglik = -1.145, Test loglik = -3.766, Train RMSE = 0.620, Test RMSE = 1.420
# Epoch: 091/500, Train loglik = -0.983, Test loglik = -2.721, Train RMSE = 0.525, Test RMSE = 1.405
# Epoch: 121/500, Train loglik = -1.881, Test loglik = -2.538, Train RMSE = 0.828, Test RMSE = 1.524
# Epoch: 151/500, Train loglik = -0.911, Test loglik = -3.402, Train RMSE = 0.389, Test RMSE = 1.447
# Epoch: 181/500, Train loglik = -0.494, Test loglik = -11.886, Train RMSE = 0.355, Test RMSE = 1.472
# Epoch: 211/500, Train loglik = -1.111, Test loglik = -2.289, Train RMSE = 0.390, Test RMSE = 1.493
# Epoch: 241/500, Train loglik = -0.821, Test loglik = -5.354, Train RMSE = 0.493, Test RMSE = 1.500
# Epoch: 271/500, Train loglik = -0.251, Test loglik = -7.504, Train RMSE = 0.275, Test RMSE = 1.457
# Epoch: 301/500, Train loglik = -0.227, Test loglik = -16.785, Train RMSE = 0.207, Test RMSE = 1.458
# Epoch: 331/500, Train loglik = -0.435, Test loglik = -5.007, Train RMSE = 0.188, Test RMSE = 1.439
# Epoch: 361/500, Train loglik = -0.489, Test loglik = -4.249, Train RMSE = 0.268, Test RMSE = 1.464
# Epoch: 391/500, Train loglik = -1.435, Test loglik = -2.111, Train RMSE = 1.112, Test RMSE = 1.686
# Epoch: 421/500, Train loglik = -0.121, Test loglik = -9.467, Train RMSE = 0.257, Test RMSE = 1.446
# Epoch: 451/500, Train loglik = -0.280, Test loglik = -28.578, Train RMSE = 0.157, Test RMSE = 1.425
# Epoch: 481/500, Train loglik = 0.196, Test loglik = -25.589, Train RMSE = 0.190, Test RMSE = 1.413
# Epoch: 500/500, Train loglik = -0.143, Test loglik = -43.012, Train RMSE = 0.161, Test RMSE = 1.432
# FOLD 5:
# Epoch: 001/500, Train loglik = -13.602, Test loglik = -12.227, Train RMSE = 6.449, Test RMSE = 6.508
# Epoch: 031/500, Train loglik = -2.167, Test loglik = -2.091, Train RMSE = 1.251, Test RMSE = 1.160
# Epoch: 061/500, Train loglik = -1.442, Test loglik = -1.677, Train RMSE = 0.720, Test RMSE = 1.121
# Epoch: 091/500, Train loglik = -1.011, Test loglik = -1.515, Train RMSE = 0.462, Test RMSE = 0.958
# Epoch: 121/500, Train loglik = -1.194, Test loglik = -1.949, Train RMSE = 0.639, Test RMSE = 1.150
# Epoch: 151/500, Train loglik = -0.604, Test loglik = -2.109, Train RMSE = 0.319, Test RMSE = 0.964
# Epoch: 181/500, Train loglik = -0.983, Test loglik = -1.517, Train RMSE = 0.365, Test RMSE = 1.057
# Epoch: 211/500, Train loglik = -0.801, Test loglik = -1.643, Train RMSE = 0.283, Test RMSE = 1.005
# Epoch: 241/500, Train loglik = -0.766, Test loglik = -2.904, Train RMSE = 0.560, Test RMSE = 1.112
# Epoch: 271/500, Train loglik = -0.467, Test loglik = -4.471, Train RMSE = 0.202, Test RMSE = 0.930
# Epoch: 301/500, Train loglik = -1.040, Test loglik = -1.533, Train RMSE = 0.752, Test RMSE = 1.107
# Epoch: 331/500, Train loglik = -0.483, Test loglik = -1.878, Train RMSE = 0.278, Test RMSE = 1.022
# Epoch: 361/500, Train loglik = -0.486, Test loglik = -2.130, Train RMSE = 0.249, Test RMSE = 0.985
# Epoch: 391/500, Train loglik = -0.236, Test loglik = -4.064, Train RMSE = 0.184, Test RMSE = 0.974
# Epoch: 421/500, Train loglik = -0.252, Test loglik = -3.165, Train RMSE = 0.228, Test RMSE = 1.019
# Epoch: 451/500, Train loglik = -0.420, Test loglik = -5.599, Train RMSE = 0.249, Test RMSE = 1.021
# Epoch: 481/500, Train loglik = -0.264, Test loglik = -4.586, Train RMSE = 0.170, Test RMSE = 0.926
# Epoch: 500/500, Train loglik = -0.077, Test loglik = -5.481, Train RMSE = 0.204, Test RMSE = 0.993
# FOLD 6:
# Epoch: 001/500, Train loglik = -14.535, Test loglik = -13.964, Train RMSE = 6.338, Test RMSE = 6.841
# Epoch: 031/500, Train loglik = -1.914, Test loglik = -1.978, Train RMSE = 1.018, Test RMSE = 1.138
# Epoch: 061/500, Train loglik = -1.659, Test loglik = -2.556, Train RMSE = 0.601, Test RMSE = 0.806
# Epoch: 091/500, Train loglik = -1.097, Test loglik = -1.452, Train RMSE = 0.694, Test RMSE = 1.074
# Epoch: 121/500, Train loglik = -1.031, Test loglik = -1.549, Train RMSE = 0.369, Test RMSE = 0.836
# Epoch: 151/500, Train loglik = -0.697, Test loglik = -1.477, Train RMSE = 0.267, Test RMSE = 0.791
# Epoch: 181/500, Train loglik = -1.655, Test loglik = -3.309, Train RMSE = 0.298, Test RMSE = 0.832
# Epoch: 211/500, Train loglik = -0.447, Test loglik = -1.750, Train RMSE = 0.195, Test RMSE = 0.778
# Epoch: 241/500, Train loglik = -0.946, Test loglik = -3.716, Train RMSE = 0.444, Test RMSE = 0.833
# Epoch: 271/500, Train loglik = -0.935, Test loglik = -5.602, Train RMSE = 0.422, Test RMSE = 0.844
# Epoch: 301/500, Train loglik = -0.229, Test loglik = -2.717, Train RMSE = 0.273, Test RMSE = 0.739
# Epoch: 331/500, Train loglik = -0.701, Test loglik = -2.133, Train RMSE = 0.229, Test RMSE = 0.747
# Epoch: 361/500, Train loglik = -0.003, Test loglik = -5.131, Train RMSE = 0.208, Test RMSE = 0.728
# Epoch: 391/500, Train loglik = 0.011, Test loglik = -8.036, Train RMSE = 0.224, Test RMSE = 0.749
# Epoch: 421/500, Train loglik = -0.745, Test loglik = -1.308, Train RMSE = 0.262, Test RMSE = 0.775
# Epoch: 451/500, Train loglik = 0.296, Test loglik = -7.728, Train RMSE = 0.116, Test RMSE = 0.719
# Epoch: 481/500, Train loglik = 0.170, Test loglik = -4.163, Train RMSE = 0.098, Test RMSE = 0.724
# Epoch: 500/500, Train loglik = -0.505, Test loglik = -2.398, Train RMSE = 0.278, Test RMSE = 0.801
# FOLD 7:
# Epoch: 001/500, Train loglik = -13.185, Test loglik = -15.105, Train RMSE = 6.246, Test RMSE = 7.026
# Epoch: 031/500, Train loglik = -1.909, Test loglik = -2.036, Train RMSE = 0.984, Test RMSE = 1.254
# Epoch: 061/500, Train loglik = -1.333, Test loglik = -1.581, Train RMSE = 0.670, Test RMSE = 1.116
# Epoch: 091/500, Train loglik = -1.349, Test loglik = -1.992, Train RMSE = 0.729, Test RMSE = 1.182
# Epoch: 121/500, Train loglik = -1.060, Test loglik = -2.109, Train RMSE = 0.435, Test RMSE = 1.057
# Epoch: 151/500, Train loglik = -1.063, Test loglik = -1.859, Train RMSE = 0.341, Test RMSE = 1.039
# Epoch: 181/500, Train loglik = -0.772, Test loglik = -1.944, Train RMSE = 0.384, Test RMSE = 1.122
# Epoch: 211/500, Train loglik = -0.523, Test loglik = -4.623, Train RMSE = 0.344, Test RMSE = 1.083
# Epoch: 241/500, Train loglik = -0.825, Test loglik = -2.177, Train RMSE = 0.293, Test RMSE = 1.077
# Epoch: 271/500, Train loglik = -0.234, Test loglik = -6.246, Train RMSE = 0.212, Test RMSE = 1.079
# Epoch: 301/500, Train loglik = -0.376, Test loglik = -2.966, Train RMSE = 0.202, Test RMSE = 1.109
# Epoch: 331/500, Train loglik = -0.506, Test loglik = -9.853, Train RMSE = 0.342, Test RMSE = 1.185
# Epoch: 361/500, Train loglik = -0.850, Test loglik = -1.869, Train RMSE = 0.396, Test RMSE = 1.260
# Epoch: 391/500, Train loglik = -0.910, Test loglik = -4.303, Train RMSE = 0.274, Test RMSE = 1.155
# Epoch: 421/500, Train loglik = -1.971, Test loglik = -9.139, Train RMSE = 0.485, Test RMSE = 1.274
# Epoch: 451/500, Train loglik = -0.207, Test loglik = -5.204, Train RMSE = 0.151, Test RMSE = 1.095
# Epoch: 481/500, Train loglik = -0.600, Test loglik = -8.601, Train RMSE = 0.176, Test RMSE = 1.071
# Epoch: 500/500, Train loglik = -3.028, Test loglik = -3.265, Train RMSE = 0.559, Test RMSE = 1.187
# FOLD 8:
# Epoch: 001/500, Train loglik = -12.426, Test loglik = -15.723, Train RMSE = 6.388, Test RMSE = 6.251
# Epoch: 031/500, Train loglik = -2.193, Test loglik = -2.526, Train RMSE = 1.623, Test RMSE = 3.186
# Epoch: 061/500, Train loglik = -1.120, Test loglik = -2.299, Train RMSE = 0.600, Test RMSE = 1.283
# Epoch: 091/500, Train loglik = -1.760, Test loglik = -5.126, Train RMSE = 0.706, Test RMSE = 1.815
# Epoch: 121/500, Train loglik = -1.428, Test loglik = -4.132, Train RMSE = 0.354, Test RMSE = 1.395
# Epoch: 151/500, Train loglik = -0.604, Test loglik = -4.772, Train RMSE = 0.319, Test RMSE = 1.442
# Epoch: 181/500, Train loglik = -0.738, Test loglik = -7.415, Train RMSE = 0.249, Test RMSE = 1.337
# Epoch: 211/500, Train loglik = -0.912, Test loglik = -2.462, Train RMSE = 0.512, Test RMSE = 1.337
# Epoch: 241/500, Train loglik = -0.666, Test loglik = -31.948, Train RMSE = 0.211, Test RMSE = 1.347
# Epoch: 271/500, Train loglik = -0.602, Test loglik = -5.528, Train RMSE = 0.338, Test RMSE = 1.273
# Epoch: 301/500, Train loglik = -0.367, Test loglik = -26.506, Train RMSE = 0.379, Test RMSE = 1.247
# Epoch: 331/500, Train loglik = -0.257, Test loglik = -11.745, Train RMSE = 0.242, Test RMSE = 1.248
# Epoch: 361/500, Train loglik = -0.387, Test loglik = -4.061, Train RMSE = 0.244, Test RMSE = 1.306
# Epoch: 391/500, Train loglik = -1.036, Test loglik = -1.990, Train RMSE = 0.450, Test RMSE = 1.254
# Epoch: 421/500, Train loglik = 0.149, Test loglik = -44.030, Train RMSE = 0.179, Test RMSE = 1.213
# Epoch: 451/500, Train loglik = 0.352, Test loglik = -57.989, Train RMSE = 0.171, Test RMSE = 1.233
# Epoch: 481/500, Train loglik = 0.253, Test loglik = -49.857, Train RMSE = 0.170, Test RMSE = 1.236
# Epoch: 500/500, Train loglik = -0.372, Test loglik = -4.570, Train RMSE = 0.143, Test RMSE = 1.207
# FOLD 9:
# Epoch: 001/500, Train loglik = -11.600, Test loglik = -12.391, Train RMSE = 6.306, Test RMSE = 6.113
# Epoch: 031/500, Train loglik = -2.082, Test loglik = -2.112, Train RMSE = 1.137, Test RMSE = 1.245
# Epoch: 061/500, Train loglik = -1.254, Test loglik = -1.395, Train RMSE = 0.958, Test RMSE = 0.953
# Epoch: 091/500, Train loglik = -1.047, Test loglik = -1.642, Train RMSE = 0.617, Test RMSE = 0.906
# Epoch: 121/500, Train loglik = -0.955, Test loglik = -2.190, Train RMSE = 0.397, Test RMSE = 0.891
# Epoch: 151/500, Train loglik = -0.694, Test loglik = -2.802, Train RMSE = 0.401, Test RMSE = 0.889
# Epoch: 181/500, Train loglik = -0.466, Test loglik = -2.627, Train RMSE = 0.272, Test RMSE = 0.779
# Epoch: 211/500, Train loglik = -0.527, Test loglik = -3.180, Train RMSE = 0.355, Test RMSE = 0.845
# Epoch: 241/500, Train loglik = -0.244, Test loglik = -4.041, Train RMSE = 0.222, Test RMSE = 0.778
# Epoch: 271/500, Train loglik = -0.531, Test loglik = -2.504, Train RMSE = 0.262, Test RMSE = 0.752
# Epoch: 301/500, Train loglik = -0.323, Test loglik = -2.423, Train RMSE = 0.201, Test RMSE = 0.746
# Epoch: 331/500, Train loglik = -2.549, Test loglik = -2.560, Train RMSE = 0.553, Test RMSE = 0.794
# Epoch: 361/500, Train loglik = -0.760, Test loglik = -1.284, Train RMSE = 0.355, Test RMSE = 0.717
# Epoch: 391/500, Train loglik = -0.901, Test loglik = -1.419, Train RMSE = 0.324, Test RMSE = 0.784
# Epoch: 421/500, Train loglik = -0.010, Test loglik = -3.212, Train RMSE = 0.214, Test RMSE = 0.716
# Epoch: 451/500, Train loglik = -0.258, Test loglik = -4.506, Train RMSE = 0.222, Test RMSE = 0.721
# Epoch: 481/500, Train loglik = -0.349, Test loglik = -1.582, Train RMSE = 0.231, Test RMSE = 0.718
# Epoch: 500/500, Train loglik = 0.054, Test loglik = -5.415, Train RMSE = 0.170, Test RMSE = 0.717
# Train log. lik. = -0.457 +/-  0.902
# Test  log. lik. = -7.880 +/- 13.294
# Train RMSE      =  0.243 +/-  0.122
# Test  RMSE      =  1.047 +/-  0.222
