# %% [markdown]
# <a href="https://colab.research.google.com/github/EdWangLoDaSc/Dropout-as-a-Grid-Search_Representing-Model-Uncertainty-in-Deep-Learning/blob/main/bbp_hetero_Hybrid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
# !pip install GPy
import GPy
import pandas as pd
import zipfile
import urllib.request
import time
import copy
import math
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim import Optimizer
from sklearn.model_selection import KFold

from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm, trange
from google.colab import files
# %config InlineBackend.figure_format = 'svg'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: torch-0.4.1-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.13.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: torch==1.12.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchvision) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GPy
#   Downloading GPy-1.10.0.tar.gz (959 kB)
#      |████████████████████████████████| 959 kB 14.3 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from GPy) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from GPy) (1.15.0)
# Collecting paramz>=0.9.0
#   Downloading paramz-0.9.5.tar.gz (71 kB)
#      |████████████████████████████████| 71 kB 10.5 MB/s
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from GPy) (0.29.30)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from GPy) (1.7.3)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from paramz>=0.9.0->GPy) (4.4.2)
# Building wheels for collected packages: GPy, paramz
#   Building wheel for GPy (setup.py) ... done
#   Created wheel for GPy: filename=GPy-1.10.0-cp37-cp37m-linux_x86_64.whl size=2565125 sha256=8e5a1be8e78323e3cc7e367319d36b44d168ab410d1871be5057228f738bd679
#   Stored in directory: /root/.cache/pip/wheels/f7/18/28/dd1ce0192a81b71a3b086fd952511d088b21e8359ea496860a
#   Building wheel for paramz (setup.py) ... done
#   Created wheel for paramz: filename=paramz-0.9.5-py3-none-any.whl size=102566 sha256=6ee7d57cc53ec73e3206aef4eb24de83afa2908146b94648a7f33f59a1dcc455
#   Stored in directory: /root/.cache/pip/wheels/c8/95/f5/ce28482da28162e6028c4b3a32c41d147395825b3cd62bc810
# Successfully built GPy paramz
# Installing collected packages: paramz, GPy
# Successfully installed GPy-1.10.0 paramz-0.9.5

# %%
torch.cuda.device(0)
torch.cuda.get_device_name(torch.cuda.current_device())
# Out:
# 'Tesla P100-PCIE-16GB'

# %%
def to_variable(var=(), cuda=True, volatile=False):
    out = []
    for v in var:
        
        if isinstance(v, np.ndarray):
            v = torch.from_numpy(v).type(torch.FloatTensor)

        if not v.is_cuda and cuda:
            v = v.cuda()

        if not isinstance(v, Variable):
            v = Variable(v, volatile=volatile)

        out.append(v)
    return out

# %%
def log_gaussian_loss(output, target, sigma, no_dim, sum_reduce=True):
    exponent = -0.5*(target - output)**2/sigma**2
    log_coeff = -no_dim*torch.log(sigma) - 0.5*no_dim*np.log(2*np.pi)
    
    if sum_reduce:
        return -(log_coeff + exponent).sum()
    else:
        return -(log_coeff + exponent)


def get_kl_divergence(weights, prior, varpost):
    prior_loglik = prior.loglik(weights)
    
    varpost_loglik = varpost.loglik(weights)
    varpost_lik = varpost_loglik.exp()
    
    return (varpost_lik*(varpost_loglik - prior_loglik)).sum()


class gaussian:
    def __init__(self, mu, sigma):
        self.mu = mu
        self.sigma = sigma
        
    def loglik(self, weights):
        exponent = -0.5*(weights - self.mu)**2/self.sigma**2
        log_coeff = -0.5*(np.log(2*np.pi) + 2*np.log(self.sigma))
        
        return (exponent + log_coeff).sum()

# %%
class BayesLinear_Normalq(nn.Module):
    def __init__(self, input_dim, output_dim, prior):
        super(BayesLinear_Normalq, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.prior = prior
        
        scale = (2/self.input_dim)**0.5
        rho_init = np.log(np.exp((2/self.input_dim)**0.5) - 1)
        self.weight_mus = nn.Parameter(torch.Tensor(self.input_dim, self.output_dim).uniform_(-0.01, 0.01))
        self.weight_rhos = nn.Parameter(torch.Tensor(self.input_dim, self.output_dim).uniform_(-3, -3))
        
        self.bias_mus = nn.Parameter(torch.Tensor(self.output_dim).uniform_(-0.01, 0.01))
        self.bias_rhos = nn.Parameter(torch.Tensor(self.output_dim).uniform_(-4, -3))
        
    def forward(self, x, sample = True):
        
        if sample:
            # sample gaussian noise for each weight and each bias
            weight_epsilons = Variable(self.weight_mus.data.new(self.weight_mus.size()).normal_())
            bias_epsilons =  Variable(self.bias_mus.data.new(self.bias_mus.size()).normal_())
            
            # calculate the weight and bias stds from the rho parameters
            weight_stds = torch.log(1 + torch.exp(self.weight_rhos))
            bias_stds = torch.log(1 + torch.exp(self.bias_rhos))
            
            # calculate samples from the posterior from the sampled noise and mus/stds
            weight_sample = self.weight_mus + weight_epsilons*weight_stds
            bias_sample = self.bias_mus + bias_epsilons*bias_stds
            
            output = torch.mm(x, weight_sample) + bias_sample
            
            # computing the KL loss term
            prior_cov, varpost_cov = self.prior.sigma**2, weight_stds**2
            KL_loss = 0.5*(torch.log(prior_cov/varpost_cov)).sum() - 0.5*weight_stds.numel()
            KL_loss = KL_loss + 0.5*(varpost_cov/prior_cov).sum()
            KL_loss = KL_loss + 0.5*((self.weight_mus - self.prior.mu)**2/prior_cov).sum()
            
            prior_cov, varpost_cov = self.prior.sigma**2, bias_stds**2
            KL_loss = KL_loss + 0.5*(torch.log(prior_cov/varpost_cov)).sum() - 0.5*bias_stds.numel()
            KL_loss = KL_loss + 0.5*(varpost_cov/prior_cov).sum()
            KL_loss = KL_loss + 0.5*((self.bias_mus - self.prior.mu)**2/prior_cov).sum()
            
            return output, KL_loss
        
        else:
            output = torch.mm(x, self.weight_mus) + self.bias_mus
            return output, KL_loss
        
    def sample_layer(self, no_samples):
        all_samples = []
        for i in range(no_samples):
            # sample gaussian noise for each weight and each bias
            weight_epsilons = Variable(self.weight_mus.data.new(self.weight_mus.size()).normal_())
            
            # calculate the weight and bias stds from the rho parameters
            weight_stds = torch.log(1 + torch.exp(self.weight_rhos))
            
            # calculate samples from the posterior from the sampled noise and mus/stds
            weight_sample = self.weight_mus + weight_epsilons*weight_stds
            
            all_samples += weight_sample.view(-1).cpu().data.numpy().tolist()
            
        return all_samples

# %%
class BBP_Heteroscedastic_Model(nn.Module):
    def __init__(self, input_dim, output_dim, num_units):
        super(BBP_Heteroscedastic_Model, self).__init__()
        
        self.input_dim = input_dim
        self.output_dim = output_dim
        
        # network with two hidden and one output layer
        self.layer1 = BayesLinear_Normalq(input_dim, num_units, gaussian(0, 1))
        self.layer2 = BayesLinear_Normalq(num_units, 2*output_dim, gaussian(0, 1))
        
        # activation to be used between hidden layers
        self.activation = nn.ReLU(inplace = True)
    
    def forward(self, x):
        
        KL_loss_total = 0
        x = x.view(-1, self.input_dim)
        
        x, KL_loss = self.layer1(x)
        KL_loss_total = KL_loss_total + KL_loss
        x = self.activation(x)
        
        x, KL_loss = self.layer2(x)
        KL_loss_total = KL_loss_total + KL_loss
        
        return x, KL_loss_total

# %%
class BBP_Heteroscedastic_Model_Wrapper:
    def __init__(self, network, learn_rate, batch_size, no_batches):
        
        self.learn_rate = learn_rate
        self.batch_size = batch_size
        self.no_batches = no_batches
        
        self.network = network
        self.network.cuda()
        
        self.optimizer = torch.optim.Adam(self.network.parameters(), lr = self.learn_rate)
        self.loss_func = log_gaussian_loss
    
    def fit(self, x, y, no_samples):
        x, y = to_variable(var=(x, y), cuda=True)
        
        # reset gradient and total loss
        self.optimizer.zero_grad()
        fit_loss_total = 0
        
        for i in range(no_samples):
            output, KL_loss_total = self.network(x)

            # calculate fit loss based on mean and standard deviation of output
            fit_loss = self.loss_func(output[:, :1], y, output[:, 1:].exp(), 1)
            fit_loss_total = fit_loss_total + fit_loss
        
        KL_loss_total = KL_loss_total/self.no_batches
        total_loss = (fit_loss_total + KL_loss_total)/(no_samples*x.shape[0])
        total_loss.backward()
        self.optimizer.step()

        return fit_loss_total/no_samples, KL_loss_total
    
    def get_loss_and_rmse(self, x, y, no_samples):
        x, y = to_variable(var=(x, y), cuda=True)
        
        means, stds = [], []
        for i in range(no_samples):
            output, KL_loss_total = self.network(x)
            means.append(output[:, :1, None])
            stds.append(output[:, 1:, None].exp())
            
        means, stds = torch.cat(means, 2), torch.cat(stds, 2)
        mean = means.mean(dim=2)
        std = (means.var(dim=2) + stds.mean(dim=2)**2)**0.5
            
        # calculate fit loss based on mean and standard deviation of output
        logliks = self.loss_func(output[:, :1], y, output[:, 1:].exp(), 1, sum_reduce=False)
        rmse = float((((mean - y)**2).mean()**0.5).cpu().data)

        return logliks, rmse

# %%
class BBP_Heteroscedastic_Model_UCI(nn.Module):
    def __init__(self, input_dim, output_dim, num_units):
        super(BBP_Heteroscedastic_Model_UCI, self).__init__()
        
        self.input_dim = input_dim
        self.output_dim = output_dim
        
        # network with two hidden and one output layer
        self.layer1 = BayesLinear_Normalq(input_dim, num_units, gaussian(0, 1))
        self.layer2 = BayesLinear_Normalq(num_units, num_units, gaussian(0, 1))
        self.layer3 = BayesLinear_Normalq(num_units, 2*output_dim, gaussian(0, 1))
        
        # activation to be used between hidden layers
        self.activation = nn.ReLU(inplace = True)
    
    def forward(self, x):
        
        KL_loss_total = 0
        x = x.view(-1, self.input_dim)
        
        x, KL_loss = self.layer1(x)
        KL_loss_total = KL_loss_total + KL_loss
        x = self.activation(x)
        
        x, KL_loss = self.layer2(x)
        KL_loss_total = KL_loss_total + KL_loss
        
        return x, KL_loss_total

def train_BBP(data, n_splits, num_epochs, num_units, learn_rate, log_every):
    kf = KFold(n_splits=n_splits)
    in_dim = data.shape[1] - 1
    train_logliks, test_logliks = [], []
    train_rmses, test_rmses = [], []

    for i, idx in enumerate(kf.split(data)):
        print('FOLD %d:' % i)

        train_index, test_index = idx

        x_train, y_train = data[train_index, :in_dim], data[train_index, in_dim:]
        x_test, y_test = data[test_index, :in_dim], data[test_index, in_dim:]

        x_means, x_stds = x_train.mean(axis = 0), x_train.var(axis = 0)**0.5
        y_means, y_stds = y_train.mean(axis = 0), y_train.var(axis = 0)**0.5

        x_train = (x_train - x_means)/x_stds
        y_train = (y_train - y_means)/y_stds

        x_test = (x_test - x_means)/x_stds
        y_test = (y_test - y_means)/y_stds

        batch_size, nb_train = len(x_train), len(x_train)

        net = BBP_Heteroscedastic_Model_Wrapper(network=BBP_Heteroscedastic_Model_UCI(input_dim=x_test.shape[-1], output_dim=1, num_units=num_units),
                                                learn_rate=1e-2, batch_size=batch_size, no_batches=1)

        fit_loss_train = np.zeros(num_epochs)
        KL_loss_train = np.zeros(num_epochs)
        total_loss = np.zeros(num_epochs)

        best_net, best_loss = None, float('inf')

        for i in range(num_epochs):

            fit_loss, KL_loss = net.fit(x_train, y_train, no_samples = 20)
            fit_loss_train[i] += fit_loss.cpu().data.numpy()
            KL_loss_train[i] += KL_loss.cpu().data.numpy()

            total_loss[i] = fit_loss_train[i] + KL_loss_train[i]

            if fit_loss < best_loss:
                best_loss = fit_loss
                best_net = copy.deepcopy(net.network)

            if i % log_every == 0 or i == num_epochs - 1:

                train_losses, train_rmse = net.get_loss_and_rmse(x_train, y_train, 20)
                test_losses, test_rmse = net.get_loss_and_rmse(x_test, y_test, 20)

                print('Epoch: %s/%d, Train loglik = %.3f, Test loglik = %.3f, Train RMSE = %.3f, Test RMSE = %.3f' %\
                      (str(i+1).zfill(3), num_epochs, -train_losses.mean() - np.log(y_stds)[0],
                       -test_losses.mean() - np.log(y_stds)[0], y_stds*train_rmse, y_stds*test_rmse))


        train_losses, train_rmse = net.get_loss_and_rmse(x_train, y_train, 20)
        test_losses, test_rmse = net.get_loss_and_rmse(x_test, y_test, 20)

        train_logliks.append((train_losses.cpu().data.numpy().mean() + np.log(y_stds)[0]))
        test_logliks.append((test_losses.cpu().data.numpy().mean() + np.log(y_stds)[0]))

        train_rmses.append(y_stds*train_rmse)
        test_rmses.append(y_stds*test_rmse)

    print('Train log. lik. = %6.3f +/- %6.3f' % (-np.array(train_logliks).mean(), np.array(train_logliks).var()**0.5))
    print('Test  log. lik. = %6.3f +/- %6.3f' % (-np.array(test_logliks).mean(), np.array(test_logliks).var()**0.5))
    print('Train RMSE      = %6.3f +/- %6.3f' % (np.array(train_rmses).mean(), np.array(train_rmses).var()**0.5))
    print('Test  RMSE      = %6.3f +/- %6.3f' % (np.array(test_rmses).mean(), np.array(test_rmses).var()**0.5))

    return best_net

# %%
import os
os.chdir('/content/drive/MyDrive')

# %%
pip install miceforest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting miceforest
#   Downloading miceforest-5.5.4-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.8 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from miceforest) (0.3.5.1)
# Collecting lightgbm>=3.3.1
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 27.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from miceforest) (1.21.6)
# Collecting blosc
#   Downloading blosc-1.10.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 57.1 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.3.1->miceforest) (1.7.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.3.1->miceforest) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.3.1->miceforest) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm>=3.3.1->miceforest) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm>=3.3.1->miceforest) (1.1.0)
# Installing collected packages: lightgbm, blosc, miceforest
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# Successfully installed blosc-1.10.6 lightgbm-3.3.2 miceforest-5.5.4

# %%
import os
os.chdir('/content/drive/MyDrive/DropoutUncertaintyExps-master/Hydrid_modeling')

# %%
from DataProcessing import DataProcessing as dp
doc_2020 = pd.read_csv('/content/drive/MyDrive/DropoutUncertaintyExps-master/Hydrid_modeling/EndUserData2020P2.csv', encoding = 'ISO-8859-1', skiprows = [0,2]).astype('float')
doc_2021 = pd.read_csv('/content/drive/MyDrive/DropoutUncertaintyExps-master/Hydrid_modeling/EndUserData2021P2_fix.csv', encoding = 'ISO-8859-1', skiprows = [0,2]).astype('float')
#print(doc_2020)

doc_2020_value = dp(doc_2020, doc_2021).data_process_20().astype('float64')
#dco_2021_value = dp(doc_2020, doc_2021).data_process_21().astype('float64')

BNN_20 = pd.DataFrame(np.c_[doc_2020_value['NB2_S_1_NYZ_sys_x_PcwOut_x'], doc_2020_value['NB2_S_1_NYZ_sys_x_PcwIn_x'], doc_2020_value['NB2_S_1_NYZ_cwp_9_HzSPR_x'], doc_2020_value['NB2_S_1_NYZ_cwp_10_HzSPR_x'], doc_2020_value['NB2_S_1_NYZ_cwp_11_HzSPR_x'], doc_2020_value['NB2_S_1_NYZ_cwp_12_HzSPR_x'], doc_2020_value['p_diff'], doc_2020_value['NB2_S_x_NYZ_x_x_Fcw_x']], columns = ['NB2_S_1_NYZ_sys_x_PcwOut_x', 'NB2_S_1_NYZ_sys_x_PcwIn_x', 'NB2_S_1_NYZ_cwp_9_HzSPR_x', 'NB2_S_1_NYZ_cwp_10_HzSPR_x', 'NB2_S_1_NYZ_cwp_11_HzSPR_x', 'NB2_S_1_NYZ_cwp_12_HzSPR_x', 'diff', 'NB2_S_x_NYZ_x_x_Fcw_x']).values
data=BNN_20
batch_size = 2048
model = train_BBP(data, n_splits=10, num_epochs=500, num_units=120, learn_rate=1e-2, log_every=30)
# Out:
#  /content/drive/MyDrive/DataProcessing.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  /content/drive/MyDrive/DataProcessing.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  /content/drive/MyDrive/DataProcessing.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  /content/drive/MyDrive/DataProcessing.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  /content/drive/MyDrive/DataProcessing.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FOLD 0:
# Epoch: 001/500, Train loglik = -8.228, Test loglik = -8.091, Train RMSE = 929.159, Test RMSE = 729.341
# Epoch: 031/500, Train loglik = -6.759, Test loglik = -7.273, Train RMSE = 170.985, Test RMSE = 182.911
# Epoch: 061/500, Train loglik = -6.953, Test loglik = -6.720, Train RMSE = 183.431, Test RMSE = 150.203
# Epoch: 091/500, Train loglik = -6.578, Test loglik = -6.592, Train RMSE = 174.506, Test RMSE = 111.421
# Epoch: 121/500, Train loglik = -6.216, Test loglik = -6.076, Train RMSE = 158.928, Test RMSE = 100.325
# Epoch: 151/500, Train loglik = -6.285, Test loglik = -6.252, Train RMSE = 147.642, Test RMSE = 96.925
# Epoch: 181/500, Train loglik = -6.208, Test loglik = -6.065, Train RMSE = 119.790, Test RMSE = 90.959
# Epoch: 211/500, Train loglik = -6.072, Test loglik = -5.990, Train RMSE = 102.884, Test RMSE = 86.281
# Epoch: 241/500, Train loglik = -6.011, Test loglik = -5.909, Train RMSE = 109.087, Test RMSE = 81.286
# Epoch: 271/500, Train loglik = -5.825, Test loglik = -5.841, Train RMSE = 102.231, Test RMSE = 81.188
# Epoch: 301/500, Train loglik = -5.825, Test loglik = -5.801, Train RMSE = 101.478, Test RMSE = 83.507
# Epoch: 331/500, Train loglik = -5.928, Test loglik = -5.648, Train RMSE = 102.447, Test RMSE = 83.943
# Epoch: 361/500, Train loglik = -5.978, Test loglik = -5.762, Train RMSE = 102.886, Test RMSE = 88.637
# Epoch: 391/500, Train loglik = -5.804, Test loglik = -5.646, Train RMSE = 103.197, Test RMSE = 86.956
# Epoch: 421/500, Train loglik = -5.839, Test loglik = -5.741, Train RMSE = 104.028, Test RMSE = 83.834
# Epoch: 451/500, Train loglik = -5.798, Test loglik = -5.707, Train RMSE = 99.545, Test RMSE = 79.908
# Epoch: 481/500, Train loglik = -5.728, Test loglik = -5.653, Train RMSE = 104.466, Test RMSE = 80.007
# Epoch: 500/500, Train loglik = -5.869, Test loglik = -5.672, Train RMSE = 103.114, Test RMSE = 86.611
# FOLD 1:
# Epoch: 001/500, Train loglik = -8.227, Test loglik = -8.372, Train RMSE = 902.447, Test RMSE = 989.700
# Epoch: 031/500, Train loglik = -6.687, Test loglik = -6.649, Train RMSE = 179.792, Test RMSE = 138.320
# Epoch: 061/500, Train loglik = -6.611, Test loglik = -6.426, Train RMSE = 163.108, Test RMSE = 111.896
# Epoch: 091/500, Train loglik = -6.517, Test loglik = -6.483, Train RMSE = 172.243, Test RMSE = 93.530
# Epoch: 121/500, Train loglik = -6.288, Test loglik = -6.348, Train RMSE = 167.733, Test RMSE = 98.032
# Epoch: 151/500, Train loglik = -6.094, Test loglik = -5.954, Train RMSE = 141.054, Test RMSE = 88.960
# Epoch: 181/500, Train loglik = -6.530, Test loglik = -5.919, Train RMSE = 130.406, Test RMSE = 89.348
# Epoch: 211/500, Train loglik = -6.095, Test loglik = -5.838, Train RMSE = 113.152, Test RMSE = 89.132
# Epoch: 241/500, Train loglik = -5.910, Test loglik = -6.039, Train RMSE = 102.607, Test RMSE = 89.424
# Epoch: 271/500, Train loglik = -5.839, Test loglik = -5.889, Train RMSE = 103.945, Test RMSE = 84.109
# Epoch: 301/500, Train loglik = -5.913, Test loglik = -5.841, Train RMSE = 103.657, Test RMSE = 84.649
# Epoch: 331/500, Train loglik = -6.142, Test loglik = -5.877, Train RMSE = 103.478, Test RMSE = 93.548
# Epoch: 361/500, Train loglik = -5.786, Test loglik = -5.715, Train RMSE = 99.342, Test RMSE = 85.032
# Epoch: 391/500, Train loglik = -5.758, Test loglik = -5.860, Train RMSE = 99.099, Test RMSE = 83.968
# Epoch: 421/500, Train loglik = -5.723, Test loglik = -5.836, Train RMSE = 99.352, Test RMSE = 83.955
# Epoch: 451/500, Train loglik = -5.689, Test loglik = -5.820, Train RMSE = 98.518, Test RMSE = 83.431
# Epoch: 481/500, Train loglik = -5.761, Test loglik = -5.998, Train RMSE = 100.384, Test RMSE = 85.162
# Epoch: 500/500, Train loglik = -5.651, Test loglik = -5.805, Train RMSE = 99.319, Test RMSE = 81.199
# FOLD 2:
# Epoch: 001/500, Train loglik = -8.226, Test loglik = -8.349, Train RMSE = 885.445, Test RMSE = 1026.723
# Epoch: 031/500, Train loglik = -6.843, Test loglik = -7.094, Train RMSE = 173.602, Test RMSE = 146.080
# Epoch: 061/500, Train loglik = -6.574, Test loglik = -6.681, Train RMSE = 163.419, Test RMSE = 127.785
# Epoch: 091/500, Train loglik = -6.587, Test loglik = -6.619, Train RMSE = 160.622, Test RMSE = 118.342
# Epoch: 121/500, Train loglik = -6.302, Test loglik = -6.122, Train RMSE = 171.282, Test RMSE = 92.429
# Epoch: 151/500, Train loglik = -6.171, Test loglik = -6.265, Train RMSE = 129.725, Test RMSE = 110.232
# Epoch: 181/500, Train loglik = -6.007, Test loglik = -5.993, Train RMSE = 115.596, Test RMSE = 90.772
# Epoch: 211/500, Train loglik = -5.940, Test loglik = -5.978, Train RMSE = 100.213, Test RMSE = 82.764
# Epoch: 241/500, Train loglik = -6.087, Test loglik = -6.043, Train RMSE = 101.590, Test RMSE = 82.443
# Epoch: 271/500, Train loglik = -5.862, Test loglik = -6.022, Train RMSE = 100.710, Test RMSE = 84.398
# Epoch: 301/500, Train loglik = -5.874, Test loglik = -5.871, Train RMSE = 101.762, Test RMSE = 87.520
# Epoch: 331/500, Train loglik = -6.130, Test loglik = -5.818, Train RMSE = 109.008, Test RMSE = 85.598
# Epoch: 361/500, Train loglik = -5.778, Test loglik = -5.802, Train RMSE = 101.017, Test RMSE = 84.391
# Epoch: 391/500, Train loglik = -5.772, Test loglik = -6.093, Train RMSE = 102.780, Test RMSE = 84.498
# Epoch: 421/500, Train loglik = -5.709, Test loglik = -5.798, Train RMSE = 99.704, Test RMSE = 83.373
# Epoch: 451/500, Train loglik = -5.725, Test loglik = -5.846, Train RMSE = 101.227, Test RMSE = 81.373
# Epoch: 481/500, Train loglik = -5.724, Test loglik = -5.881, Train RMSE = 99.104, Test RMSE = 83.112
# Epoch: 500/500, Train loglik = -5.722, Test loglik = -5.760, Train RMSE = 99.047, Test RMSE = 85.191
# FOLD 3:
# Epoch: 001/500, Train loglik = -8.220, Test loglik = -8.224, Train RMSE = 906.663, Test RMSE = 878.237
# Epoch: 031/500, Train loglik = -7.036, Test loglik = -6.576, Train RMSE = 188.511, Test RMSE = 145.077
# Epoch: 061/500, Train loglik = -6.745, Test loglik = -6.390, Train RMSE = 164.249, Test RMSE = 109.504
# Epoch: 091/500, Train loglik = -6.698, Test loglik = -6.240, Train RMSE = 170.171, Test RMSE = 94.595
# Epoch: 121/500, Train loglik = -6.512, Test loglik = -6.213, Train RMSE = 166.549, Test RMSE = 91.274
# Epoch: 151/500, Train loglik = -6.232, Test loglik = -6.257, Train RMSE = 164.923, Test RMSE = 92.049
# Epoch: 181/500, Train loglik = -6.353, Test loglik = -6.079, Train RMSE = 155.690, Test RMSE = 104.829
# Epoch: 211/500, Train loglik = -6.162, Test loglik = -6.028, Train RMSE = 168.336, Test RMSE = 84.923
# Epoch: 241/500, Train loglik = -5.954, Test loglik = -6.094, Train RMSE = 143.124, Test RMSE = 83.575
# Epoch: 271/500, Train loglik = -5.922, Test loglik = -5.835, Train RMSE = 134.608, Test RMSE = 84.192
# Epoch: 301/500, Train loglik = -6.110, Test loglik = -5.966, Train RMSE = 125.998, Test RMSE = 99.211
# Epoch: 331/500, Train loglik = -6.411, Test loglik = -5.907, Train RMSE = 105.080, Test RMSE = 79.376
# Epoch: 361/500, Train loglik = -5.845, Test loglik = -5.867, Train RMSE = 100.971, Test RMSE = 82.037
# Epoch: 391/500, Train loglik = -5.692, Test loglik = -5.731, Train RMSE = 99.461, Test RMSE = 84.753
# Epoch: 421/500, Train loglik = -5.719, Test loglik = -5.737, Train RMSE = 102.412, Test RMSE = 84.940
# Epoch: 451/500, Train loglik = -5.825, Test loglik = -5.806, Train RMSE = 99.561, Test RMSE = 79.673
# Epoch: 481/500, Train loglik = -5.782, Test loglik = -5.843, Train RMSE = 100.460, Test RMSE = 84.767
# Epoch: 500/500, Train loglik = -5.705, Test loglik = -5.757, Train RMSE = 98.691, Test RMSE = 79.549
# FOLD 4:
# Epoch: 001/500, Train loglik = -8.206, Test loglik = -8.498, Train RMSE = 891.576, Test RMSE = 1065.971
# Epoch: 031/500, Train loglik = -6.700, Test loglik = -6.796, Train RMSE = 178.419, Test RMSE = 170.008
# Epoch: 061/500, Train loglik = -6.587, Test loglik = -6.893, Train RMSE = 165.018, Test RMSE = 148.632
# Epoch: 091/500, Train loglik = -6.373, Test loglik = -6.328, Train RMSE = 161.885, Test RMSE = 134.324
# Epoch: 121/500, Train loglik = -6.410, Test loglik = -6.362, Train RMSE = 166.169, Test RMSE = 121.957
# Epoch: 151/500, Train loglik = -6.242, Test loglik = -6.191, Train RMSE = 168.896, Test RMSE = 117.724
# Epoch: 181/500, Train loglik = -6.127, Test loglik = -6.291, Train RMSE = 155.968, Test RMSE = 111.188
# Epoch: 211/500, Train loglik = -6.059, Test loglik = -6.041, Train RMSE = 138.135, Test RMSE = 114.601
# Epoch: 241/500, Train loglik = -5.913, Test loglik = -6.023, Train RMSE = 120.415, Test RMSE = 122.201
# Epoch: 271/500, Train loglik = -5.984, Test loglik = -6.023, Train RMSE = 107.734, Test RMSE = 132.828
# Epoch: 301/500, Train loglik = -5.816, Test loglik = -6.007, Train RMSE = 101.772, Test RMSE = 137.425
# Epoch: 331/500, Train loglik = -5.772, Test loglik = -6.005, Train RMSE = 93.020, Test RMSE = 142.882
# Epoch: 361/500, Train loglik = -5.769, Test loglik = -5.949, Train RMSE = 93.121, Test RMSE = 149.057
# Epoch: 391/500, Train loglik = -6.096, Test loglik = -6.051, Train RMSE = 93.588, Test RMSE = 148.728
# Epoch: 421/500, Train loglik = -5.699, Test loglik = -5.887, Train RMSE = 92.598, Test RMSE = 146.338
# Epoch: 451/500, Train loglik = -5.833, Test loglik = -5.894, Train RMSE = 91.617, Test RMSE = 146.554
# Epoch: 481/500, Train loglik = -5.810, Test loglik = -6.103, Train RMSE = 93.608, Test RMSE = 148.671
# Epoch: 500/500, Train loglik = -5.662, Test loglik = -6.016, Train RMSE = 92.412, Test RMSE = 143.463
# FOLD 5:
# Epoch: 001/500, Train loglik = -8.179, Test loglik = -8.387, Train RMSE = 895.074, Test RMSE = 1037.470
# Epoch: 031/500, Train loglik = -7.004, Test loglik = -6.998, Train RMSE = 181.925, Test RMSE = 140.030
# Epoch: 061/500, Train loglik = -6.716, Test loglik = -6.556, Train RMSE = 161.050, Test RMSE = 144.455
# Epoch: 091/500, Train loglik = -6.533, Test loglik = -6.272, Train RMSE = 175.879, Test RMSE = 143.947
# Epoch: 121/500, Train loglik = -6.324, Test loglik = -6.439, Train RMSE = 167.284, Test RMSE = 111.604
# Epoch: 151/500, Train loglik = -6.508, Test loglik = -6.082, Train RMSE = 155.143, Test RMSE = 111.415
# Epoch: 181/500, Train loglik = -6.068, Test loglik = -6.057, Train RMSE = 153.733, Test RMSE = 102.440
# Epoch: 211/500, Train loglik = -6.007, Test loglik = -6.040, Train RMSE = 141.295, Test RMSE = 98.706
# Epoch: 241/500, Train loglik = -5.900, Test loglik = -5.891, Train RMSE = 131.395, Test RMSE = 98.915
# Epoch: 271/500, Train loglik = -6.094, Test loglik = -5.855, Train RMSE = 105.415, Test RMSE = 97.332
# Epoch: 301/500, Train loglik = -5.866, Test loglik = -5.756, Train RMSE = 100.231, Test RMSE = 94.276
# Epoch: 331/500, Train loglik = -5.763, Test loglik = -5.745, Train RMSE = 102.152, Test RMSE = 96.161
# Epoch: 361/500, Train loglik = -5.827, Test loglik = -5.862, Train RMSE = 101.182, Test RMSE = 102.663
# Epoch: 391/500, Train loglik = -5.797, Test loglik = -5.814, Train RMSE = 99.170, Test RMSE = 93.386
# Epoch: 421/500, Train loglik = -5.701, Test loglik = -5.782, Train RMSE = 97.334, Test RMSE = 93.976
# Epoch: 451/500, Train loglik = -5.705, Test loglik = -5.744, Train RMSE = 98.149, Test RMSE = 94.995
# Epoch: 481/500, Train loglik = -6.080, Test loglik = -5.737, Train RMSE = 98.256, Test RMSE = 93.572
# Epoch: 500/500, Train loglik = -5.719, Test loglik = -5.668, Train RMSE = 96.686, Test RMSE = 94.896
# FOLD 6:
# Epoch: 001/500, Train loglik = -8.255, Test loglik = -8.175, Train RMSE = 916.169, Test RMSE = 883.462
# Epoch: 031/500, Train loglik = -6.740, Test loglik = -7.165, Train RMSE = 168.527, Test RMSE = 189.091
# Epoch: 061/500, Train loglik = -6.624, Test loglik = -6.678, Train RMSE = 166.336, Test RMSE = 160.210
# Epoch: 091/500, Train loglik = -6.428, Test loglik = -6.768, Train RMSE = 163.741, Test RMSE = 144.738
# Epoch: 121/500, Train loglik = -6.284, Test loglik = -6.607, Train RMSE = 159.756, Test RMSE = 141.505
# Epoch: 151/500, Train loglik = -6.120, Test loglik = -6.507, Train RMSE = 171.393, Test RMSE = 131.732
# Epoch: 181/500, Train loglik = -6.103, Test loglik = -6.325, Train RMSE = 143.440, Test RMSE = 121.931
# Epoch: 211/500, Train loglik = -6.271, Test loglik = -6.422, Train RMSE = 133.511, Test RMSE = 115.140
# Epoch: 241/500, Train loglik = -5.891, Test loglik = -6.111, Train RMSE = 103.842, Test RMSE = 107.989
# Epoch: 271/500, Train loglik = -5.988, Test loglik = -5.946, Train RMSE = 100.429, Test RMSE = 103.986
# Epoch: 301/500, Train loglik = -5.847, Test loglik = -6.028, Train RMSE = 102.676, Test RMSE = 98.956
# Epoch: 331/500, Train loglik = -5.807, Test loglik = -5.932, Train RMSE = 100.676, Test RMSE = 101.553
# Epoch: 361/500, Train loglik = -5.755, Test loglik = -5.887, Train RMSE = 99.484, Test RMSE = 100.490
# Epoch: 391/500, Train loglik = -5.799, Test loglik = -5.870, Train RMSE = 102.055, Test RMSE = 98.191
# Epoch: 421/500, Train loglik = -5.759, Test loglik = -5.962, Train RMSE = 99.297, Test RMSE = 98.539
# Epoch: 451/500, Train loglik = -5.765, Test loglik = -5.881, Train RMSE = 98.650, Test RMSE = 97.779
# Epoch: 481/500, Train loglik = -5.706, Test loglik = -5.841, Train RMSE = 99.032, Test RMSE = 97.470
# Epoch: 500/500, Train loglik = -5.635, Test loglik = -5.892, Train RMSE = 97.489, Test RMSE = 99.242
# FOLD 7:
# Epoch: 001/500, Train loglik = -8.224, Test loglik = -8.142, Train RMSE = 919.070, Test RMSE = 815.456
# Epoch: 031/500, Train loglik = -6.965, Test loglik = -6.896, Train RMSE = 170.119, Test RMSE = 166.965
# Epoch: 061/500, Train loglik = -6.450, Test loglik = -6.674, Train RMSE = 156.765, Test RMSE = 139.653
# Epoch: 091/500, Train loglik = -6.496, Test loglik = -6.478, Train RMSE = 159.844, Test RMSE = 132.176
# Epoch: 121/500, Train loglik = -6.572, Test loglik = -6.386, Train RMSE = 141.929, Test RMSE = 126.934
# Epoch: 151/500, Train loglik = -6.199, Test loglik = -6.765, Train RMSE = 124.984, Test RMSE = 127.604
# Epoch: 181/500, Train loglik = -6.042, Test loglik = -6.505, Train RMSE = 106.990, Test RMSE = 122.724
# Epoch: 211/500, Train loglik = -5.890, Test loglik = -6.000, Train RMSE = 103.011, Test RMSE = 115.314
# Epoch: 241/500, Train loglik = -5.903, Test loglik = -6.026, Train RMSE = 100.160, Test RMSE = 110.196
# Epoch: 271/500, Train loglik = -5.914, Test loglik = -6.393, Train RMSE = 98.206, Test RMSE = 110.078
# Epoch: 301/500, Train loglik = -5.912, Test loglik = -6.543, Train RMSE = 98.848, Test RMSE = 109.735
# Epoch: 331/500, Train loglik = -5.798, Test loglik = -5.970, Train RMSE = 99.364, Test RMSE = 104.256
# Epoch: 361/500, Train loglik = -5.877, Test loglik = -6.109, Train RMSE = 98.523, Test RMSE = 106.987
# Epoch: 391/500, Train loglik = -5.848, Test loglik = -6.212, Train RMSE = 99.243, Test RMSE = 103.624
# Epoch: 421/500, Train loglik = -5.677, Test loglik = -5.990, Train RMSE = 97.953, Test RMSE = 102.042
# Epoch: 451/500, Train loglik = -5.778, Test loglik = -5.986, Train RMSE = 96.510, Test RMSE = 102.761
# Epoch: 481/500, Train loglik = -5.695, Test loglik = -6.113, Train RMSE = 97.479, Test RMSE = 103.508
# Epoch: 500/500, Train loglik = -5.598, Test loglik = -6.144, Train RMSE = 96.487, Test RMSE = 101.401
# FOLD 8:
# Epoch: 001/500, Train loglik = -8.213, Test loglik = -8.272, Train RMSE = 899.216, Test RMSE = 927.821
# Epoch: 031/500, Train loglik = -6.716, Test loglik = -8.551, Train RMSE = 145.429, Test RMSE = 446.416
# Epoch: 061/500, Train loglik = -6.646, Test loglik = -7.428, Train RMSE = 119.384, Test RMSE = 480.417
# Epoch: 091/500, Train loglik = -6.488, Test loglik = -7.941, Train RMSE = 120.384, Test RMSE = 446.625
# Epoch: 121/500, Train loglik = -6.183, Test loglik = -9.588, Train RMSE = 111.198, Test RMSE = 475.539
# Epoch: 151/500, Train loglik = -6.147, Test loglik = -8.155, Train RMSE = 104.910, Test RMSE = 470.354
# Epoch: 181/500, Train loglik = -6.252, Test loglik = -9.696, Train RMSE = 108.111, Test RMSE = 485.651
# Epoch: 211/500, Train loglik = -6.040, Test loglik = -7.763, Train RMSE = 101.176, Test RMSE = 473.682
# Epoch: 241/500, Train loglik = -5.826, Test loglik = -8.640, Train RMSE = 99.063, Test RMSE = 463.234
# Epoch: 271/500, Train loglik = -6.003, Test loglik = -7.336, Train RMSE = 102.549, Test RMSE = 449.556
# Epoch: 301/500, Train loglik = -5.821, Test loglik = -8.155, Train RMSE = 98.360, Test RMSE = 440.320
# Epoch: 331/500, Train loglik = -5.794, Test loglik = -6.910, Train RMSE = 99.492, Test RMSE = 425.931
# Epoch: 361/500, Train loglik = -5.856, Test loglik = -7.865, Train RMSE = 97.089, Test RMSE = 420.675
# Epoch: 391/500, Train loglik = -5.704, Test loglik = -6.990, Train RMSE = 97.283, Test RMSE = 397.720
# Epoch: 421/500, Train loglik = -5.752, Test loglik = -7.293, Train RMSE = 96.138, Test RMSE = 411.286
# Epoch: 451/500, Train loglik = -5.756, Test loglik = -7.170, Train RMSE = 96.109, Test RMSE = 391.318
# Epoch: 481/500, Train loglik = -5.651, Test loglik = -6.548, Train RMSE = 96.377, Test RMSE = 378.663
# Epoch: 500/500, Train loglik = -5.776, Test loglik = -6.638, Train RMSE = 95.596, Test RMSE = 377.798
# FOLD 9:
# Epoch: 001/500, Train loglik = -8.248, Test loglik = -8.121, Train RMSE = 926.137, Test RMSE = 764.453
# Epoch: 031/500, Train loglik = -6.704, Test loglik = -6.768, Train RMSE = 184.767, Test RMSE = 181.196
# Epoch: 061/500, Train loglik = -6.584, Test loglik = -7.079, Train RMSE = 168.797, Test RMSE = 188.361
# Epoch: 091/500, Train loglik = -6.867, Test loglik = -6.695, Train RMSE = 163.762, Test RMSE = 153.758
# Epoch: 121/500, Train loglik = -6.301, Test loglik = -6.480, Train RMSE = 155.541, Test RMSE = 137.002
# Epoch: 151/500, Train loglik = -6.450, Test loglik = -6.429, Train RMSE = 143.839, Test RMSE = 133.179
# Epoch: 181/500, Train loglik = -6.074, Test loglik = -6.768, Train RMSE = 138.428, Test RMSE = 128.134
# Epoch: 211/500, Train loglik = -5.977, Test loglik = -6.167, Train RMSE = 113.825, Test RMSE = 124.171
# Epoch: 241/500, Train loglik = -5.930, Test loglik = -6.226, Train RMSE = 100.331, Test RMSE = 120.707
# Epoch: 271/500, Train loglik = -6.110, Test loglik = -6.250, Train RMSE = 95.103, Test RMSE = 120.173
# Epoch: 301/500, Train loglik = -5.881, Test loglik = -6.066, Train RMSE = 95.436, Test RMSE = 118.832
# Epoch: 331/500, Train loglik = -5.998, Test loglik = -6.118, Train RMSE = 105.885, Test RMSE = 125.775
# Epoch: 361/500, Train loglik = -5.796, Test loglik = -6.144, Train RMSE = 98.193, Test RMSE = 119.861
# Epoch: 391/500, Train loglik = -5.799, Test loglik = -6.372, Train RMSE = 95.026, Test RMSE = 121.294
# Epoch: 421/500, Train loglik = -5.735, Test loglik = -6.117, Train RMSE = 94.370, Test RMSE = 117.846
# Epoch: 451/500, Train loglik = -5.688, Test loglik = -6.249, Train RMSE = 95.281, Test RMSE = 119.361
# Epoch: 481/500, Train loglik = -5.725, Test loglik = -6.167, Train RMSE = 95.038, Test RMSE = 117.322
# Epoch: 500/500, Train loglik = -5.635, Test loglik = -6.208, Train RMSE = 93.836, Test RMSE = 117.143
# Train log. lik. = -5.679 +/-  0.061
# Test  log. lik. = -5.998 +/-  0.316
# Train RMSE      = 97.284 +/-  2.834
# Test  RMSE      = 127.065 +/- 85.969

# %%
model = train_BBP(data, n_splits=10, num_epochs=500, num_units=100, learn_rate=1e-2, log_every=50)
# Out:
# FOLD 0:
# Epoch: 001/500, Train loglik = -8.254, Test loglik = -8.080, Train RMSE = 923.442, Test RMSE = 747.700
# Epoch: 051/500, Train loglik = -6.517, Test loglik = -6.658, Train RMSE = 173.514, Test RMSE = 163.639
# Epoch: 101/500, Train loglik = -6.530, Test loglik = -6.667, Train RMSE = 165.940, Test RMSE = 143.203
# Epoch: 151/500, Train loglik = -6.448, Test loglik = -6.164, Train RMSE = 163.357, Test RMSE = 126.150
# Epoch: 201/500, Train loglik = -6.407, Test loglik = -5.887, Train RMSE = 146.029, Test RMSE = 94.495
# Epoch: 251/500, Train loglik = -6.029, Test loglik = -5.800, Train RMSE = 130.439, Test RMSE = 79.874
# Epoch: 301/500, Train loglik = -5.892, Test loglik = -5.801, Train RMSE = 100.825, Test RMSE = 86.627
# Epoch: 351/500, Train loglik = -6.018, Test loglik = -5.681, Train RMSE = 102.315, Test RMSE = 76.159
# Epoch: 401/500, Train loglik = -5.721, Test loglik = -5.794, Train RMSE = 99.767, Test RMSE = 76.565
# Epoch: 451/500, Train loglik = -5.718, Test loglik = -5.673, Train RMSE = 100.954, Test RMSE = 75.313
# Epoch: 500/500, Train loglik = -5.690, Test loglik = -5.682, Train RMSE = 101.587, Test RMSE = 77.222
# FOLD 1:
# Epoch: 001/500, Train loglik = -8.231, Test loglik = -8.290, Train RMSE = 900.269, Test RMSE = 987.187
# Epoch: 051/500, Train loglik = -6.588, Test loglik = -6.659, Train RMSE = 169.433, Test RMSE = 126.661
# Epoch: 101/500, Train loglik = -6.470, Test loglik = -6.305, Train RMSE = 161.394, Test RMSE = 111.113
# Epoch: 151/500, Train loglik = -6.507, Test loglik = -6.347, Train RMSE = 154.788, Test RMSE = 92.371
# Epoch: 201/500, Train loglik = -6.044, Test loglik = -6.403, Train RMSE = 117.530, Test RMSE = 85.911
# Epoch: 251/500, Train loglik = -6.051, Test loglik = -5.765, Train RMSE = 100.023, Test RMSE = 82.096
# Epoch: 301/500, Train loglik = -5.938, Test loglik = -6.074, Train RMSE = 99.482, Test RMSE = 81.333
# Epoch: 351/500, Train loglik = -5.733, Test loglik = -5.862, Train RMSE = 96.979, Test RMSE = 81.885
# Epoch: 401/500, Train loglik = -5.706, Test loglik = -5.742, Train RMSE = 99.130, Test RMSE = 83.050
# Epoch: 451/500, Train loglik = -5.798, Test loglik = -6.389, Train RMSE = 102.317, Test RMSE = 91.656
# Epoch: 500/500, Train loglik = -5.776, Test loglik = -6.026, Train RMSE = 96.318, Test RMSE = 82.662
# FOLD 2:
# Epoch: 001/500, Train loglik = -8.213, Test loglik = -8.352, Train RMSE = 897.026, Test RMSE = 1046.351
# Epoch: 051/500, Train loglik = -6.620, Test loglik = -6.726, Train RMSE = 171.022, Test RMSE = 139.304
# Epoch: 101/500, Train loglik = -6.604, Test loglik = -6.546, Train RMSE = 173.556, Test RMSE = 124.133
# Epoch: 151/500, Train loglik = -6.134, Test loglik = -6.224, Train RMSE = 145.588, Test RMSE = 115.066
# Epoch: 201/500, Train loglik = -5.986, Test loglik = -6.085, Train RMSE = 125.164, Test RMSE = 84.401
# Epoch: 251/500, Train loglik = -5.900, Test loglik = -5.845, Train RMSE = 101.735, Test RMSE = 82.663
# Epoch: 301/500, Train loglik = -5.800, Test loglik = -5.772, Train RMSE = 100.917, Test RMSE = 84.628
# Epoch: 351/500, Train loglik = -5.809, Test loglik = -5.843, Train RMSE = 103.976, Test RMSE = 83.541
# Epoch: 401/500, Train loglik = -5.735, Test loglik = -6.009, Train RMSE = 101.754, Test RMSE = 87.211
# Epoch: 451/500, Train loglik = -5.693, Test loglik = -5.771, Train RMSE = 100.178, Test RMSE = 83.548
# Epoch: 500/500, Train loglik = -5.660, Test loglik = -6.058, Train RMSE = 99.956, Test RMSE = 82.680
# FOLD 3:
# Epoch: 001/500, Train loglik = -8.267, Test loglik = -8.202, Train RMSE = 917.246, Test RMSE = 871.088
# Epoch: 051/500, Train loglik = -6.560, Test loglik = -6.615, Train RMSE = 173.591, Test RMSE = 141.231
# Epoch: 101/500, Train loglik = -6.484, Test loglik = -6.257, Train RMSE = 196.327, Test RMSE = 115.604
# Epoch: 151/500, Train loglik = -6.212, Test loglik = -6.099, Train RMSE = 132.861, Test RMSE = 86.960
# Epoch: 201/500, Train loglik = -5.950, Test loglik = -6.023, Train RMSE = 110.765, Test RMSE = 85.999
# Epoch: 251/500, Train loglik = -5.966, Test loglik = -5.938, Train RMSE = 101.149, Test RMSE = 80.843
# Epoch: 301/500, Train loglik = -5.950, Test loglik = -5.861, Train RMSE = 104.250, Test RMSE = 80.566
# Epoch: 351/500, Train loglik = -5.781, Test loglik = -5.855, Train RMSE = 99.920, Test RMSE = 78.498
# Epoch: 401/500, Train loglik = -5.960, Test loglik = -5.867, Train RMSE = 99.979, Test RMSE = 78.529
# Epoch: 451/500, Train loglik = -5.708, Test loglik = -5.791, Train RMSE = 100.693, Test RMSE = 82.908
# Epoch: 500/500, Train loglik = -5.674, Test loglik = -5.791, Train RMSE = 99.631, Test RMSE = 79.228
# FOLD 4:
# Epoch: 001/500, Train loglik = -8.207, Test loglik = -8.370, Train RMSE = 905.461, Test RMSE = 1063.844
# Epoch: 051/500, Train loglik = -6.691, Test loglik = -6.450, Train RMSE = 164.890, Test RMSE = 146.307
# Epoch: 101/500, Train loglik = -6.417, Test loglik = -6.421, Train RMSE = 170.604, Test RMSE = 134.147
# Epoch: 151/500, Train loglik = -6.408, Test loglik = -6.268, Train RMSE = 156.801, Test RMSE = 123.846
# Epoch: 201/500, Train loglik = -6.170, Test loglik = -6.191, Train RMSE = 140.139, Test RMSE = 115.820
# Epoch: 251/500, Train loglik = -5.956, Test loglik = -6.109, Train RMSE = 106.612, Test RMSE = 131.335
# Epoch: 301/500, Train loglik = -5.983, Test loglik = -6.036, Train RMSE = 94.396, Test RMSE = 143.967
# Epoch: 351/500, Train loglik = -5.755, Test loglik = -5.997, Train RMSE = 93.080, Test RMSE = 146.494
# Epoch: 401/500, Train loglik = -5.743, Test loglik = -5.983, Train RMSE = 95.313, Test RMSE = 143.914
# Epoch: 451/500, Train loglik = -5.656, Test loglik = -5.968, Train RMSE = 91.269, Test RMSE = 145.507
# Epoch: 500/500, Train loglik = -5.716, Test loglik = -5.929, Train RMSE = 91.828, Test RMSE = 145.037
# FOLD 5:
# Epoch: 001/500, Train loglik = -8.210, Test loglik = -8.446, Train RMSE = 897.627, Test RMSE = 1056.072
# Epoch: 051/500, Train loglik = -6.685, Test loglik = -6.565, Train RMSE = 187.014, Test RMSE = 148.444
# Epoch: 101/500, Train loglik = -6.412, Test loglik = -6.220, Train RMSE = 166.658, Test RMSE = 111.718
# Epoch: 151/500, Train loglik = -6.113, Test loglik = -6.317, Train RMSE = 146.396, Test RMSE = 98.413
# Epoch: 201/500, Train loglik = -5.941, Test loglik = -6.281, Train RMSE = 123.796, Test RMSE = 93.352
# Epoch: 251/500, Train loglik = -6.226, Test loglik = -5.981, Train RMSE = 120.327, Test RMSE = 102.892
# Epoch: 301/500, Train loglik = -5.908, Test loglik = -5.813, Train RMSE = 100.608, Test RMSE = 98.493
# Epoch: 351/500, Train loglik = -5.850, Test loglik = -5.731, Train RMSE = 99.688, Test RMSE = 96.135
# Epoch: 401/500, Train loglik = -5.762, Test loglik = -5.866, Train RMSE = 99.517, Test RMSE = 101.996
# Epoch: 451/500, Train loglik = -5.713, Test loglik = -5.654, Train RMSE = 98.339, Test RMSE = 95.813
# Epoch: 500/500, Train loglik = -5.668, Test loglik = -5.821, Train RMSE = 98.458, Test RMSE = 96.592
# FOLD 6:
# Epoch: 001/500, Train loglik = -8.238, Test loglik = -8.205, Train RMSE = 912.988, Test RMSE = 884.238
# Epoch: 051/500, Train loglik = -6.666, Test loglik = -6.901, Train RMSE = 160.205, Test RMSE = 175.442
# Epoch: 101/500, Train loglik = -6.366, Test loglik = -6.500, Train RMSE = 157.871, Test RMSE = 138.616
# Epoch: 151/500, Train loglik = -6.337, Test loglik = -6.346, Train RMSE = 141.005, Test RMSE = 139.423
# Epoch: 201/500, Train loglik = -5.980, Test loglik = -6.323, Train RMSE = 123.491, Test RMSE = 112.387
# Epoch: 251/500, Train loglik = -5.943, Test loglik = -6.746, Train RMSE = 99.237, Test RMSE = 110.084
# Epoch: 301/500, Train loglik = -5.800, Test loglik = -6.100, Train RMSE = 97.249, Test RMSE = 101.224
# Epoch: 351/500, Train loglik = -5.889, Test loglik = -5.974, Train RMSE = 100.842, Test RMSE = 100.534
# Epoch: 401/500, Train loglik = -5.724, Test loglik = -5.925, Train RMSE = 100.557, Test RMSE = 111.708
# Epoch: 451/500, Train loglik = -5.746, Test loglik = -5.891, Train RMSE = 99.960, Test RMSE = 98.210
# Epoch: 500/500, Train loglik = -5.762, Test loglik = -5.889, Train RMSE = 96.399, Test RMSE = 103.091
# FOLD 7:
# Epoch: 001/500, Train loglik = -8.257, Test loglik = -8.117, Train RMSE = 923.876, Test RMSE = 805.175
# Epoch: 051/500, Train loglik = -6.840, Test loglik = -6.652, Train RMSE = 174.812, Test RMSE = 191.346
# Epoch: 101/500, Train loglik = -6.397, Test loglik = -6.720, Train RMSE = 165.312, Test RMSE = 153.995
# Epoch: 151/500, Train loglik = -6.210, Test loglik = -6.620, Train RMSE = 133.710, Test RMSE = 124.798
# Epoch: 201/500, Train loglik = -6.462, Test loglik = -6.675, Train RMSE = 116.563, Test RMSE = 133.470
# Epoch: 251/500, Train loglik = -5.856, Test loglik = -6.036, Train RMSE = 101.145, Test RMSE = 105.379
# Epoch: 301/500, Train loglik = -6.081, Test loglik = -6.577, Train RMSE = 98.925, Test RMSE = 103.910
# Epoch: 351/500, Train loglik = -5.792, Test loglik = -6.064, Train RMSE = 98.271, Test RMSE = 103.812
# Epoch: 401/500, Train loglik = -5.787, Test loglik = -5.993, Train RMSE = 95.780, Test RMSE = 104.047
# Epoch: 451/500, Train loglik = -5.649, Test loglik = -6.034, Train RMSE = 96.823, Test RMSE = 106.558
# Epoch: 500/500, Train loglik = -5.749, Test loglik = -6.269, Train RMSE = 96.600, Test RMSE = 103.372
# FOLD 8:
# Epoch: 001/500, Train loglik = -8.204, Test loglik = -8.278, Train RMSE = 903.144, Test RMSE = 931.610
# Epoch: 051/500, Train loglik = -6.504, Test loglik = -8.440, Train RMSE = 134.500, Test RMSE = 426.864
# Epoch: 101/500, Train loglik = -6.164, Test loglik = -8.949, Train RMSE = 109.414, Test RMSE = 434.053
# Epoch: 151/500, Train loglik = -6.247, Test loglik = -8.227, Train RMSE = 109.821, Test RMSE = 441.570
# Epoch: 201/500, Train loglik = -5.996, Test loglik = -6.836, Train RMSE = 98.955, Test RMSE = 457.106
# Epoch: 251/500, Train loglik = -5.990, Test loglik = -7.114, Train RMSE = 101.154, Test RMSE = 422.259
# Epoch: 301/500, Train loglik = -6.028, Test loglik = -7.153, Train RMSE = 100.604, Test RMSE = 429.674
# Epoch: 351/500, Train loglik = -5.726, Test loglik = -7.451, Train RMSE = 96.288, Test RMSE = 383.655
# Epoch: 401/500, Train loglik = -5.759, Test loglik = -6.689, Train RMSE = 99.588, Test RMSE = 400.689
# Epoch: 451/500, Train loglik = -5.675, Test loglik = -6.642, Train RMSE = 94.977, Test RMSE = 342.326
# Epoch: 500/500, Train loglik = -5.628, Test loglik = -6.539, Train RMSE = 93.132, Test RMSE = 323.071
# FOLD 9:
# Epoch: 001/500, Train loglik = -8.227, Test loglik = -8.120, Train RMSE = 929.890, Test RMSE = 760.648
# Epoch: 051/500, Train loglik = -6.712, Test loglik = -6.755, Train RMSE = 173.398, Test RMSE = 165.947
# Epoch: 101/500, Train loglik = -6.430, Test loglik = -6.530, Train RMSE = 174.922, Test RMSE = 148.795
# Epoch: 151/500, Train loglik = -6.214, Test loglik = -6.282, Train RMSE = 167.062, Test RMSE = 134.678
# Epoch: 201/500, Train loglik = -6.047, Test loglik = -6.222, Train RMSE = 143.297, Test RMSE = 126.454
# Epoch: 251/500, Train loglik = -5.953, Test loglik = -6.097, Train RMSE = 121.964, Test RMSE = 124.160
# Epoch: 301/500, Train loglik = -5.918, Test loglik = -6.129, Train RMSE = 96.683, Test RMSE = 128.419
# Epoch: 351/500, Train loglik = -5.944, Test loglik = -6.092, Train RMSE = 97.927, Test RMSE = 119.274
# Epoch: 401/500, Train loglik = -5.673, Test loglik = -6.070, Train RMSE = 96.623, Test RMSE = 120.501
# Epoch: 451/500, Train loglik = -5.747, Test loglik = -6.090, Train RMSE = 95.693, Test RMSE = 121.562
# Epoch: 500/500, Train loglik = -5.694, Test loglik = -6.141, Train RMSE = 95.253, Test RMSE = 120.700
# Train log. lik. = -5.686 +/-  0.044
# Test  log. lik. = -5.954 +/-  0.233
# Train RMSE      = 96.725 +/-  2.820
# Test  RMSE      = 121.166 +/- 70.418
